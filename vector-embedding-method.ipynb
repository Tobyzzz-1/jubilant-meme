# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import ast  # For literal_eval to convert string representation of list to actual list
from gensim.models import KeyedVectors
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from plotly import graph_objs as go
import plotly.express as px
import plotly.figure_factory as ff
from collections import Counter
import nltk
from nltk.corpus import stopwords

import re
import string


# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/afinn-lexicon/Afinn.csv
# /kaggle/input/universal-sentence-encoder/tensorflow2/universal-sentence-encoder/2/saved_model.pb
# /kaggle/input/universal-sentence-encoder/tensorflow2/universal-sentence-encoder/2/variables/variables.index
# /kaggle/input/universal-sentence-encoder/tensorflow2/universal-sentence-encoder/2/variables/variables.data-00000-of-00001
# /kaggle/input/tweet-sentiment-extraction/sample_submission.csv
# /kaggle/input/tweet-sentiment-extraction/train.csv
# /kaggle/input/tweet-sentiment-extraction/test.csv

# %%
df_train=pd.read_csv("/kaggle/input/tweet-sentiment-extraction/train.csv")
df_test=pd.read_csv("/kaggle/input/tweet-sentiment-extraction/test.csv")

# %%
df_train.head()
# Out:
#        textID                                               text  \
# 0  cb774db0d1                I`d have responded, if I were going
# 1  549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861   Sons of ****, why couldn`t they put them on t...
#
#                          selected_text sentiment
# 0  I`d have responded, if I were going   neutral
# 1                             Sooo SAD  negative
# 2                          bullying me  negative
# 3                       leave me alone  negative
# 4                        Sons of ****,  negative

# %% [markdown]
# <h1>Exploratory Data Analysis</h1>

# %%
print(df_train.shape)
print(df_test.shape)
# Out:
# (27481, 4)
# (3534, 3)

# %%
df_train.dropna(inplace=True)
df_test.dropna(inplace=True)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27480 entries, 0 to 27480
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   textID         27480 non-null  object
#  1   text           27480 non-null  object
#  2   selected_text  27480 non-null  object
#  3   sentiment      27480 non-null  object
# dtypes: object(4)
# memory usage: 1.0+ MB

# %%
sentiment_mapping = {'positive': 1, 'negative': -1, 'neutral': 0}

df_train['numerical_sentiment'] = df_train['sentiment'].map(sentiment_mapping)

# %%
Y_actual=df_train.numerical_sentiment

# %%
df_train.describe()
# Out:
#        numerical_sentiment
# count         27480.000000
# mean              0.029148
# std               0.771118
# min              -1.000000
# 25%              -1.000000
# 50%               0.000000
# 75%               1.000000
# max               1.000000

# %%
temp = df_train.groupby('sentiment').count()['text'].reset_index().sort_values(by='text',ascending=False)
temp.style.background_gradient(cmap='Purples')
# Out:
# <style type="text/css">
# #T_5798f_row0_col1 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_5798f_row1_col1 {
#   background-color: #dcdcec;
#   color: #000000;
# }
# #T_5798f_row2_col1 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# </style>
# <table id="T_5798f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5798f_level0_col0" class="col_heading level0 col0" >sentiment</th>
#       <th id="T_5798f_level0_col1" class="col_heading level0 col1" >text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5798f_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_5798f_row0_col0" class="data row0 col0" >neutral</td>
#       <td id="T_5798f_row0_col1" class="data row0 col1" >11117</td>
#     </tr>
#     <tr>
#       <th id="T_5798f_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_5798f_row1_col0" class="data row1 col0" >positive</td>
#       <td id="T_5798f_row1_col1" class="data row1 col1" >8582</td>
#     </tr>
#     <tr>
#       <th id="T_5798f_level0_row2" class="row_heading level0 row2" >0</th>
#       <td id="T_5798f_row2_col0" class="data row2 col0" >negative</td>
#       <td id="T_5798f_row2_col1" class="data row2 col1" >7781</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='sentiment',data=df_train)
# Out:
# <Axes: xlabel='sentiment', ylabel='count'>

# %%
fig = go.Figure(go.Funnelarea(
    text =temp.sentiment,
    values = temp.text,
    title = {"position": "top center", "text": "Funnel-Chart of Sentiment Distribution"}
    ))
fig.show()
# Out:
# <div>                            <div id="35b31d00-69f4-468f-934e-cba253eb259f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("35b31d00-69f4-468f-934e-cba253eb259f")) {                    Plotly.newPlot(                        "35b31d00-69f4-468f-934e-cba253eb259f",                        [{"text":["neutral","positive","negative"],"title":{"position":"top center","text":"Funnel-Chart of Sentiment Distribution"},"values":[11117,8582,7781],"type":"funnelarea"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl ...
#
# var gd = document.getElementById('35b31d00-69f4-468f-934e-cba253eb259f');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{

# %%
def clean_text(text):
    '''Make text lowercase, remove text in square brackets,remove links,remove punctuation
    and remove words containing numbers.'''
    text = str(text).lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    return text

# %%
df_train['text'] = df_train['text'].apply(lambda x:clean_text(x))
df_train['selected_text'] = df_train['selected_text'].apply(lambda x:clean_text(x))

# %%
df_train['temp_list'] = df_train['selected_text'].apply(lambda x:str(x).split())
top = Counter([item for sublist in df_train['temp_list'] for item in sublist])
temp = pd.DataFrame(top.most_common(20))
temp.columns = ['Common_words','count']
temp.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_94064_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_94064_row1_col1 {
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_94064_row2_col1 {
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_94064_row3_col1 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_94064_row4_col1 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_94064_row5_col1 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_94064_row6_col1 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_94064_row7_col1 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_94064_row8_col1 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_94064_row9_col1 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_94064_row10_col1 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_94064_row11_col1 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_94064_row12_col1 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_94064_row13_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_94064_row14_col1 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_94064_row15_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_94064_row16_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_94064_row17_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_94064_row18_col1, #T_94064_row19_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_94064">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_94064_level0_col0" class="col_heading level0 col0" >Common_words</th>
#       <th id="T_94064_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_94064_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_94064_row0_col0" class="data row0 col0" >i</td>
#       <td id="T_94064_row0_col1" class="data row0 col1" >7200</td>
#     </tr>
#     <tr>
#       <th id="T_94064_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_94064_row1_col0" class="data row1 col0" >to</td>
#       <td id="T_94064_row1_col1" class="data row1 col1" >5305</td>
#     </tr>
#     <tr>
#       <th id="T_94064_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_94064_row2_col0" class="data row2 col0" >the</td>
#       <td id="T_94064_row2_col1" class="data row2 col1" >4590</td>
#     </tr>
#     <tr>
#       <th id="T_94064_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_94064_row3_col0" class="data row3 col0" >a</td>
#       <td id="T_94064_row3_col1" class="data row3 col1" >3538</td>
#     </tr>
#     <tr>
#       <th id="T_94064_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_94064_row4_col0" class="data row4 col0" >my</td>
#       <td id="T_94064_row4_col1" class="data row4 col1" >2783</td>
#     </tr>
#     <tr>
#       <th id="T_94064_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_94064_row5_col0" class="data row5 col0" >you</td>
#       <td id="T_94064_row5_col1" class="data row5 col1" >2624</td>
#     </tr>
#     <tr>
#       <th id="T_94064_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_94064_row6_col0" class="data row6 col0" >and</td>
#       <td id="T_94064_row6_col1" class="data row6 col1" >2321</td>
#     </tr>
#     <tr>
#       <th id="T_94064_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_94064_row7_col0" class="data row7 col0" >it</td>
#       <td id="T_94064_row7_col1" class="data row7 col1" >2158</td>
#     </tr>
#     <tr>
#       <th id="T_94064_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_94064_row8_col0" class="data row8 col0" >is</td>
#       <td id="T_94064_row8_col1" class="data row8 col1" >2115</td>
#     </tr>
#     <tr>
#       <th id="T_94064_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_94064_row9_col0" class="data row9 col0" >in</td>
#       <td id="T_94064_row9_col1" class="data row9 col1" >1986</td>
#     </tr>
#     <tr>
#       <th id="T_94064_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_94064_row10_col0" class="data row10 col0" >for</td>
#       <td id="T_94064_row10_col1" class="data row10 col1" >1854</td>
#     </tr>
#     <tr>
#       <th id="T_94064_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_94064_row11_col0" class="data row11 col0" >im</td>
#       <td id="T_94064_row11_col1" class="data row11 col1" >1676</td>
#     </tr>
#     <tr>
#       <th id="T_94064_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_94064_row12_col0" class="data row12 col0" >of</td>
#       <td id="T_94064_row12_col1" class="data row12 col1" >1638</td>
#     </tr>
#     <tr>
#       <th id="T_94064_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_94064_row13_col0" class="data row13 col0" >me</td>
#       <td id="T_94064_row13_col1" class="data row13 col1" >1540</td>
#     </tr>
#     <tr>
#       <th id="T_94064_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_94064_row14_col0" class="data row14 col0" >on</td>
#       <td id="T_94064_row14_col1" class="data row14 col1" >1488</td>
#     </tr>
#     <tr>
#       <th id="T_94064_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_94064_row15_col0" class="data row15 col0" >so</td>
#       <td id="T_94064_row15_col1" class="data row15 col1" >1410</td>
#     </tr>
#     <tr>
#       <th id="T_94064_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_94064_row16_col0" class="data row16 col0" >have</td>
#       <td id="T_94064_row16_col1" class="data row16 col1" >1345</td>
#     </tr>
#     <tr>
#       <th id="T_94064_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_94064_row17_col0" class="data row17 col0" >that</td>
#       <td id="T_94064_row17_col1" class="data row17 col1" >1297</td>
#     </tr>
#     <tr>
#       <th id="T_94064_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_94064_row18_col0" class="data row18 col0" >but</td>
#       <td id="T_94064_row18_col1" class="data row18 col1" >1267</td>
#     </tr>
#     <tr>
#       <th id="T_94064_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_94064_row19_col0" class="data row19 col0" >good</td>
#       <td id="T_94064_row19_col1" class="data row19 col1" >1251</td>
#     </tr>
#   </tbody>
# </table>

# %%
def remove_stopword(x):
    return [y for y in x if y not in stopwords.words('english')]
df_train['temp_list'] = df_train['temp_list'].apply(lambda x:remove_stopword(x))

# %%
top = Counter([item for sublist in df_train['temp_list'] for item in sublist])
temp = pd.DataFrame(top.most_common(20))
temp = temp.iloc[1:,:]
temp.columns = ['Common_words','count']
temp.style.background_gradient(cmap='Purples')
# Out:
# <style type="text/css">
# #T_d3df8_row0_col1 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_d3df8_row1_col1 {
#   background-color: #6c55a5;
#   color: #f1f1f1;
# }
# #T_d3df8_row2_col1 {
#   background-color: #9692c4;
#   color: #f1f1f1;
# }
# #T_d3df8_row3_col1 {
#   background-color: #a9a7cf;
#   color: #f1f1f1;
# }
# #T_d3df8_row4_col1 {
#   background-color: #c2c3df;
#   color: #000000;
# }
# #T_d3df8_row5_col1 {
#   background-color: #c3c4e0;
#   color: #000000;
# }
# #T_d3df8_row6_col1 {
#   background-color: #c5c6e1;
#   color: #000000;
# }
# #T_d3df8_row7_col1 {
#   background-color: #dadaeb;
#   color: #000000;
# }
# #T_d3df8_row8_col1, #T_d3df8_row9_col1 {
#   background-color: #efedf5;
#   color: #000000;
# }
# #T_d3df8_row10_col1 {
#   background-color: #f2f0f7;
#   color: #000000;
# }
# #T_d3df8_row11_col1 {
#   background-color: #f6f4f9;
#   color: #000000;
# }
# #T_d3df8_row12_col1 {
#   background-color: #f7f5fa;
#   color: #000000;
# }
# #T_d3df8_row13_col1 {
#   background-color: #faf8fb;
#   color: #000000;
# }
# #T_d3df8_row14_col1, #T_d3df8_row15_col1 {
#   background-color: #faf9fc;
#   color: #000000;
# }
# #T_d3df8_row16_col1 {
#   background-color: #fbfafc;
#   color: #000000;
# }
# #T_d3df8_row17_col1, #T_d3df8_row18_col1 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# </style>
# <table id="T_d3df8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d3df8_level0_col0" class="col_heading level0 col0" >Common_words</th>
#       <th id="T_d3df8_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d3df8_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_d3df8_row0_col0" class="data row0 col0" >good</td>
#       <td id="T_d3df8_row0_col1" class="data row0 col1" >1251</td>
#     </tr>
#     <tr>
#       <th id="T_d3df8_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_d3df8_row1_col0" class="data row1 col0" >day</td>
#       <td id="T_d3df8_row1_col1" class="data row1 col1" >1058</td>
#     </tr>
#     <tr>
#       <th id="T_d3df8_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_d3df8_row2_col0" class="data row2 col0" >love</td>
#       <td id="T_d3df8_row2_col1" class="data row2 col1" >909</td>
#     </tr>
#     <tr>
#       <th id="T_d3df8_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_d3df8_row3_col0" class="data row3 col0" >happy</td>
#       <td id="T_d3df8_row3_col1" class="data row3 col1" >852</td>
#     </tr>
#     <tr>
#       <th id="T_d3df8_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_d3df8_row4_col0" class="data row4 col0" >like</td>
#       <td id="T_d3df8_row4_col1" class="data row4 col1" >774</td>
#     </tr>
#     <tr>
#       <th id="T_d3df8_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_d3df8_row5_col0" class="data row5 col0" >get</td>
#       <td id="T_d3df8_row5_col1" class="data row5 col1" >772</td>
#     </tr>
#     <tr>
#       <th id="T_d3df8_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_d3df8_row6_col0" class="data row6 col0" >dont</td>
#       <td id="T_d3df8_row6_col1" class="data row6 col1" >765</td>
#     </tr>
#     <tr>
#       <th id="T_d3df8_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_d3df8_row7_col0" class="data row7 col0" >go</td>
#       <td id="T_d3df8_row7_col1" class="data row7 col1" >700</td>
#     </tr>
#     <tr>
#       <th id="T_d3df8_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_d3df8_row8_col0" class="data row8 col0" >cant</td>
#       <td id="T_d3df8_row8_col1" class="data row8 col1" >613</td>
#     </tr>
#     <tr>
#       <th id="T_d3df8_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_d3df8_row9_col0" class="data row9 col0" >work</td>
#       <td id="T_d3df8_row9_col1" class="data row9 col1" >612</td>
#     </tr>
#     <tr>
#       <th id="T_d3df8_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_d3df8_row10_col0" class="data row10 col0" >going</td>
#       <td id="T_d3df8_row10_col1" class="data row10 col1" >592</td>
#     </tr>
#     <tr>
#       <th id="T_d3df8_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_d3df8_row11_col0" class="data row11 col0" >today</td>
#       <td id="T_d3df8_row11_col1" class="data row11 col1" >564</td>
#     </tr>
#     <tr>
#       <th id="T_d3df8_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_d3df8_row12_col0" class="data row12 col0" >got</td>
#       <td id="T_d3df8_row12_col1" class="data row12 col1" >558</td>
#     </tr>
#     <tr>
#       <th id="T_d3df8_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_d3df8_row13_col0" class="data row13 col0" >one</td>
#       <td id="T_d3df8_row13_col1" class="data row13 col1" >538</td>
#     </tr>
#     <tr>
#       <th id="T_d3df8_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_d3df8_row14_col0" class="data row14 col0" >time</td>
#       <td id="T_d3df8_row14_col1" class="data row14 col1" >534</td>
#     </tr>
#     <tr>
#       <th id="T_d3df8_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_d3df8_row15_col0" class="data row15 col0" >thanks</td>
#       <td id="T_d3df8_row15_col1" class="data row15 col1" >532</td>
#     </tr>
#     <tr>
#       <th id="T_d3df8_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_d3df8_row16_col0" class="data row16 col0" >lol</td>
#       <td id="T_d3df8_row16_col1" class="data row16 col1" >528</td>
#     </tr>
#     <tr>
#       <th id="T_d3df8_level0_row17" class="row_heading level0 row17" >18</th>
#       <td id="T_d3df8_row17_col0" class="data row17 col0" >really</td>
#       <td id="T_d3df8_row17_col1" class="data row17 col1" >520</td>
#     </tr>
#     <tr>
#       <th id="T_d3df8_level0_row18" class="row_heading level0 row18" >19</th>
#       <td id="T_d3df8_row18_col0" class="data row18 col0" >u</td>
#       <td id="T_d3df8_row18_col1" class="data row18 col1" >519</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_train['temp_list1'] = df_train['text'].apply(lambda x:str(x).split()) #List of words in every row for text
df_train['temp_list1'] = df_train['temp_list1'].apply(lambda x:remove_stopword(x)) #Removing Stopwords

# %%
top = Counter([item for sublist in df_train['temp_list1'] for item in sublist])
temp = pd.DataFrame(top.most_common(25))
temp = temp.iloc[1:,:]
temp.columns = ['Common_words','count']
temp.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_cd26c_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_cd26c_row1_col1 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_cd26c_row2_col1 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_cd26c_row3_col1 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_cd26c_row4_col1 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_cd26c_row5_col1 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_cd26c_row6_col1 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_cd26c_row7_col1 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_cd26c_row8_col1, #T_cd26c_row9_col1 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_cd26c_row10_col1 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_cd26c_row11_col1 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_cd26c_row12_col1 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_cd26c_row13_col1 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_cd26c_row14_col1 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_cd26c_row15_col1 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_cd26c_row16_col1 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_cd26c_row17_col1 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_cd26c_row18_col1 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_cd26c_row19_col1 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_cd26c_row20_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_cd26c_row21_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_cd26c_row22_col1, #T_cd26c_row23_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_cd26c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cd26c_level0_col0" class="col_heading level0 col0" >Common_words</th>
#       <th id="T_cd26c_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cd26c_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_cd26c_row0_col0" class="data row0 col0" >day</td>
#       <td id="T_cd26c_row0_col1" class="data row0 col1" >2044</td>
#     </tr>
#     <tr>
#       <th id="T_cd26c_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_cd26c_row1_col0" class="data row1 col0" >good</td>
#       <td id="T_cd26c_row1_col1" class="data row1 col1" >1549</td>
#     </tr>
#     <tr>
#       <th id="T_cd26c_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_cd26c_row2_col0" class="data row2 col0" >get</td>
#       <td id="T_cd26c_row2_col1" class="data row2 col1" >1426</td>
#     </tr>
#     <tr>
#       <th id="T_cd26c_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_cd26c_row3_col0" class="data row3 col0" >like</td>
#       <td id="T_cd26c_row3_col1" class="data row3 col1" >1346</td>
#     </tr>
#     <tr>
#       <th id="T_cd26c_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_cd26c_row4_col0" class="data row4 col0" >go</td>
#       <td id="T_cd26c_row4_col1" class="data row4 col1" >1267</td>
#     </tr>
#     <tr>
#       <th id="T_cd26c_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_cd26c_row5_col0" class="data row5 col0" >dont</td>
#       <td id="T_cd26c_row5_col1" class="data row5 col1" >1200</td>
#     </tr>
#     <tr>
#       <th id="T_cd26c_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_cd26c_row6_col0" class="data row6 col0" >love</td>
#       <td id="T_cd26c_row6_col1" class="data row6 col1" >1122</td>
#     </tr>
#     <tr>
#       <th id="T_cd26c_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_cd26c_row7_col0" class="data row7 col0" >work</td>
#       <td id="T_cd26c_row7_col1" class="data row7 col1" >1112</td>
#     </tr>
#     <tr>
#       <th id="T_cd26c_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_cd26c_row8_col0" class="data row8 col0" >going</td>
#       <td id="T_cd26c_row8_col1" class="data row8 col1" >1096</td>
#     </tr>
#     <tr>
#       <th id="T_cd26c_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_cd26c_row9_col0" class="data row9 col0" >today</td>
#       <td id="T_cd26c_row9_col1" class="data row9 col1" >1096</td>
#     </tr>
#     <tr>
#       <th id="T_cd26c_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_cd26c_row10_col0" class="data row10 col0" >got</td>
#       <td id="T_cd26c_row10_col1" class="data row10 col1" >1072</td>
#     </tr>
#     <tr>
#       <th id="T_cd26c_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_cd26c_row11_col0" class="data row11 col0" >cant</td>
#       <td id="T_cd26c_row11_col1" class="data row11 col1" >1020</td>
#     </tr>
#     <tr>
#       <th id="T_cd26c_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_cd26c_row12_col0" class="data row12 col0" >happy</td>
#       <td id="T_cd26c_row12_col1" class="data row12 col1" >976</td>
#     </tr>
#     <tr>
#       <th id="T_cd26c_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_cd26c_row13_col0" class="data row13 col0" >one</td>
#       <td id="T_cd26c_row13_col1" class="data row13 col1" >971</td>
#     </tr>
#     <tr>
#       <th id="T_cd26c_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_cd26c_row14_col0" class="data row14 col0" >lol</td>
#       <td id="T_cd26c_row14_col1" class="data row14 col1" >948</td>
#     </tr>
#     <tr>
#       <th id="T_cd26c_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_cd26c_row15_col0" class="data row15 col0" >time</td>
#       <td id="T_cd26c_row15_col1" class="data row15 col1" >942</td>
#     </tr>
#     <tr>
#       <th id="T_cd26c_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_cd26c_row16_col0" class="data row16 col0" >know</td>
#       <td id="T_cd26c_row16_col1" class="data row16 col1" >930</td>
#     </tr>
#     <tr>
#       <th id="T_cd26c_level0_row17" class="row_heading level0 row17" >18</th>
#       <td id="T_cd26c_row17_col0" class="data row17 col0" >u</td>
#       <td id="T_cd26c_row17_col1" class="data row17 col1" >923</td>
#     </tr>
#     <tr>
#       <th id="T_cd26c_level0_row18" class="row_heading level0 row18" >19</th>
#       <td id="T_cd26c_row18_col0" class="data row18 col0" >really</td>
#       <td id="T_cd26c_row18_col1" class="data row18 col1" >908</td>
#     </tr>
#     <tr>
#       <th id="T_cd26c_level0_row19" class="row_heading level0 row19" >20</th>
#       <td id="T_cd26c_row19_col0" class="data row19 col0" >back</td>
#       <td id="T_cd26c_row19_col1" class="data row19 col1" >891</td>
#     </tr>
#     <tr>
#       <th id="T_cd26c_level0_row20" class="row_heading level0 row20" >21</th>
#       <td id="T_cd26c_row20_col0" class="data row20 col0" >see</td>
#       <td id="T_cd26c_row20_col1" class="data row20 col1" >797</td>
#     </tr>
#     <tr>
#       <th id="T_cd26c_level0_row21" class="row_heading level0 row21" >22</th>
#       <td id="T_cd26c_row21_col0" class="data row21 col0" >well</td>
#       <td id="T_cd26c_row21_col1" class="data row21 col1" >744</td>
#     </tr>
#     <tr>
#       <th id="T_cd26c_level0_row22" class="row_heading level0 row22" >23</th>
#       <td id="T_cd26c_row22_col0" class="data row22 col0" >new</td>
#       <td id="T_cd26c_row22_col1" class="data row22 col1" >740</td>
#     </tr>
#     <tr>
#       <th id="T_cd26c_level0_row23" class="row_heading level0 row23" >24</th>
#       <td id="T_cd26c_row23_col0" class="data row23 col0" >night</td>
#       <td id="T_cd26c_row23_col1" class="data row23 col1" >737</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_train.head()
# Out:
#        textID                                               text  \
# 0  cb774db0d1                  id have responded if i were going
# 1  549e992a42         sooo sad i will miss you here in san diego
# 2  088c60f138                             my boss is bullying me
# 3  9642c003ef                      what interview leave me alone
# 4  358bd9e861   sons of  why couldnt they put them on the rel...
#
#                        selected_text sentiment  numerical_sentiment  \
# 0  id have responded if i were going   neutral                    0
# 1                           sooo sad  negative                   -1
# 2                        bullying me  negative                   -1
# 3                     leave me alone  negative                   -1
# 4                           sons of   negative                   -1
#
#                 temp_list                                       temp_list1
# 0  [id, responded, going]                           [id, responded, going]
# 1             [sooo, sad]                    [sooo, sad, miss, san, diego]
# 2              [bullying]                                 [boss, bullying]
# 3          [leave, alone]                        [interview, leave, alone]
# 4                  [sons]  [sons, couldnt, put, releases, already, bought]

# %%
# Load pre-trained Word2Vec model
def load_word2vec_model(model_path):
    return KeyedVectors.load_word2vec_format(model_path, binary=True)

# %%
afinn = pd.read_csv("/kaggle/input/afinn-lexicon/Afinn.csv",encoding='ISO-8859-1')


afinn.head()
# Out:
#         word  value
# 0    abandon     -2
# 1  abandoned     -2
# 2   abandons     -2
# 3   abducted     -2
# 4  abduction     -2

# %%
df_train.head()
# Out:
#        textID                                               text  \
# 0  cb774db0d1                  id have responded if i were going
# 1  549e992a42         sooo sad i will miss you here in san diego
# 2  088c60f138                             my boss is bullying me
# 3  9642c003ef                      what interview leave me alone
# 4  358bd9e861   sons of  why couldnt they put them on the rel...
#
#                        selected_text sentiment  numerical_sentiment  \
# 0  id have responded if i were going   neutral                  NaN
# 1                           sooo sad  negative                  NaN
# 2                        bullying me  negative                  NaN
# 3                     leave me alone  negative                  NaN
# 4                           sons of   negative                  NaN
#
#                 temp_list                                       temp_list1
# 0  [id, responded, going]                           [id, responded, going]
# 1             [sooo, sad]                    [sooo, sad, miss, san, diego]
# 2              [bullying]                                 [boss, bullying]
# 3          [leave, alone]                        [interview, leave, alone]
# 4                  [sons]  [sons, couldnt, put, releases, already, bought]

# %%
import tensorflow as tf
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
# Load the Universal Sentence Encoder model from Kaggle file path
def load_use_model():
    return tf.saved_model.load("/kaggle/input/universal-sentence-encoder/tensorflow2/universal-sentence-encoder/2")

def calculate_sentiment_with_use(text, afinn, use_model):
    text_embedding = use_model([text]).numpy()[0]
    
    sentiment_score = 0.0
    count = 0
    
    for index,row in afinn.iterrows():
        word=row['word']
        value=row['value']
        try:
            word_embedding = use_model([word]).numpy()[0]
            similarity_matrix = cosine_similarity([text_embedding], [word_embedding])
            
            if similarity_matrix.size == 0:
                continue
            
            similarity = similarity_matrix[0][0]
            if not np.isnan(similarity) and not np.isinf(similarity):
                sentiment_score += float(value) * similarity
                count += 1
        except KeyError:
            continue
            
    if count > 0:
        sentiment_score /= count
    
    print(f"Text: {text}")
    print(f"Sentiment Score: {sentiment_score}")
    
    return sentiment_score


def senti_score():
    afinn = pd.read_csv("/kaggle/input/afinn-lexicon/Afinn.csv",encoding='ISO-8859-1')
    use_model = load_use_model() 
    
    i = 0
    tot = 0
    
    for index, row in df_train.iterrows():
        text = row['text']
        score = calculate_sentiment_with_use(text, afinn, use_model)
       

        if score > 0:
            sentiment = "positive"
        elif score < 0:
            sentiment = "negative"
        else:
            sentiment = "neutral"
       
        if sentiment == row['sentiment'] or row['sentiment'] == 'neutral':
            i += 1

        tot=tot+1
        
        print(f"ID: {row['textID']}")
        print(f"Text: {text}")
        print(f"Sentiment Score: {score}")
        print(f"Sentiment: {sentiment}")
        print(f"Actual Sentiment: {row['sentiment']}")
        print(f"ratio: {i/tot}\n")

# %%
senti_score()
# Out:
# Text:  id have responded if i were going
# Sentiment Score: -0.07462394971014735
# ID: cb774db0d1
# Text:  id have responded if i were going
# Sentiment Score: -0.07462394971014735
# Sentiment: negative
# Actual Sentiment: neutral
# ratio: 1.0
#
# Text:  sooo sad i will miss you here in san diego
# Sentiment Score: -0.03324481030690364
# ID: 549e992a42
# Text:  sooo sad i will miss you here in san diego
# Sentiment Score: -0.03324481030690364
# Sentiment: negative
# Actual Sentiment: negative
# ratio: 1.0
#
# Text: my boss is bullying me
# Sentiment Score: -0.09070192533423
# ID: 088c60f138
# Text: my boss is bullying me
# Sentiment Score: -0.09070192533423
# Sentiment: negative
# Actual Sentiment: negative
# ratio: 1.0
#
# Text:  what interview leave me alone
# Sentiment Score: -0.049378481648259274
# ID: 9642c003ef
# Text:  what interview leave me alone
# Sentiment Score: -0.049378481648259274
# Sentiment: negative
# Actual Sentiment: negative
# ratio: 1.0
#
# Text:  sons of  why couldnt they put them on the releases we already bought
# Sentiment Score: -0.0201363199421302
# ID: 358bd9e861
# Text:  sons of  why couldnt they put them on the releases we already bought
# Sentiment Score: -0.0201363199421302
# Sentiment: negative
# Actual Sentiment: negative
# ratio: 1.0
#
# Text:   some shameless plugging for the best rangers forum on earth
# Sentiment Score: 0.007989022077681993
# ID: 28b57f3990
# Text:   some shameless plugging for the best rangers forum on earth
# Sentiment Score: 0.007989022077681993
# Sentiment: positive
# Actual Sentiment: neutral
# ratio: 1.0
#
# Text:  feedings for the baby are fun when he is all smiles and coos
# Sentiment Score: 0.035357897866782
# ID: 6e0c6d75b1
# Text:  feedings for the baby are fun when he is all smiles and coos
# Sentiment Score: 0.035357897866782
# Sentiment: positive
# Actual Sentiment: positive
# ratio: 1.0
#
# Text: soooo high
# Sentiment Score: -0.07655704943132337
# ID: 50e14c0bb8
# Text: soooo high
# Sentiment Score: -0.07655704943132337
# Sentiment: negative
# Actual Sentiment: neutral
# ratio: 1.0
#
# Text:  both of you
# Sentiment Score: -0.07067512677584654
# ID: e050245fbd
# Text:  both of you
# Sentiment Score: -0.07067512677584654
# Sentiment: negative
# Actual Sentiment: neutral
# ratio: 1.0
#
# Text:  journey wow u just became cooler  hehe is that possible
# Sentiment Score: 0.022925089528129185
# ID: fc2cbefa9d
# Text:  journey wow u just became cooler  hehe is that possible
# Sentiment Score: 0.022925089528129185
# Sentiment: positive
# Actual Sentiment: positive
# ratio: 1.0
#
# Text:  as much as i love to be hopeful i reckon the chances are minimal p im never gonna get my cake and stuff
# Sentiment Score: -0.017866930202458792
# ID: 2339a9b08b
# Text:  as much as i love to be hopeful i reckon the chances are minimal p im never gonna get my cake and stuff
# Sentiment Score: -0.017866930202458792
# Sentiment: negative
# Actual Sentiment: neutral
# ratio: 1.0
#
# Text: i really really like the song love story by taylor swift
# Sentiment Score: -0.021273413020233875
# ID: 16fab9f95b
# Text: i really really like the song love story by taylor swift
# Sentiment Score: -0.021273413020233875
# Sentiment: negative
# Actual Sentiment: positive
# ratio: 0.9166666666666666
#
# Text: my sharpie is running dangerously low on ink
# Sentiment Score: -0.05078468861101217
# ID: 74a76f6e0a
# Text: my sharpie is running dangerously low on ink
# Sentiment Score: -0.05078468861101217
# Sentiment: negative
# Actual Sentiment: negative
# ratio: 0.9230769230769231
#
# Text: i want to go to music tonight but i lost my voice
# Sentiment Score: -0.02219892411463062
# ID: 04dd1d2e34
# Text: i want to go to music tonight but i lost my voice
# Sentiment Score: -0.02219892411463062
# Sentiment: negative
# Actual Sentiment: negative
# ratio: 0.9285714285714286
#
# Text: test test from the lg
# Sentiment Score: -0.01487877748253897
# ID: bbe3cbf620
# Text: test test from the lg
# Sentiment Score: -0.01487877748253897
# Sentiment: negative
# Actual Sentiment: neutral
# ratio: 0.9333333333333333
#
# Text: uh oh i am sunburned
# Sentiment Score: -0.11069645891458602
# ID: 8a939bfb59
# Text: uh oh i am sunburned
# Sentiment Score: -0.11069645891458602
# Sentiment: negative
# Actual Sentiment: negative
# ratio: 0.9375
#
# Text:  sok trying to plot alternatives as we speak sigh
# Sentiment Score: -0.07243834385425785
# ID: 3440297f8b
# Text:  sok trying to plot alternatives as we speak sigh
# Sentiment Score: -0.07243834385425785
# Sentiment: negative
# Actual Sentiment: negative
# ratio: 0.9411764705882353
#
# Text: ive been sick for the past few days  and thus my hair looks wierd  if i didnt have a hat on it would look
# Sentiment Score: -0.05194888131141807
# ID: 919fa93391
# Text: ive been sick for the past few days  and thus my hair looks wierd  if i didnt have a hat on it would look
# Sentiment Score: -0.05194888131141807
# Sentiment: negative
# Actual Sentiment: negative
# ratio: 0.9444444444444444
#
# Text: is back home now      gonna miss every one
# Sentiment Score: -0.002945834714400465
# ID: af3fed7fc3
# Text: is back home now      gonna miss every one
# Sentiment Score: -0.002945834714400465
# Sentiment: negative
# Actual Sentiment: negative
# ratio: 0.9473684210526315
#
# Text: hes just not that into you
# Sentiment Score: -0.07443167016847863
# ID: 40e7becabf
# Text: hes just not that into you
# Sentiment Score: -0.07443167016847863
# Sentiment: negative
# Actual Sentiment: neutral
# ratio: 0.95
#
# Text:  oh marly im so sorry  i hope you find her soon
# Sentiment Score: -0.026561770165548913
# ID: 04d17ef61e
# Text:  oh marly im so sorry  i hope you find her soon
# Sentiment Score: -0.026561770165548913
# Sentiment: negative
# Actual Sentiment: neutral
# ratio: 0.9523809523809523
#
# Text: playing ghost online is really interesting the new updates are kirin pet and metamorph for third job  cant wait to have a dragon pet
# Sentiment Score: 0.006945981572468254
# ID: e48b0b8a23
# Text: playing ghost online is really interesting the new updates are kirin pet and metamorph for third job  cant wait to have a dragon pet
# Sentiment Score: 0.006945981572468254
# Sentiment: positive
# Actual Sentiment: positive
# ratio: 0.9545454545454546
#
# Text: is cleaning the house for her family who is comming later today
# Sentiment Score: 0.017875695655059986
# ID: 7de057cf40
# Text: is cleaning the house for her family who is comming later today
# Sentiment Score: 0.017875695655059986
# Sentiment: positive
# Actual Sentiment: neutral
# ratio: 0.9565217391304348
#
# Text: gotta restart my computer  i thought  was supposed to put an end to the constant rebootiness
# Sentiment Score: -0.050711569819391844
# ID: 9ce5570064
# Text: gotta restart my computer  i thought  was supposed to put an end to the constant rebootiness
# Sentiment Score: -0.050711569819391844
# Sentiment: negative
# Actual Sentiment: neutral
# ratio: 0.9583333333333334
#
# Text: see wat i mean bout  friidays its called lose  friday smh
# Sentiment Score: -0.07850531548326313
# ID: 0c8cc71c46
# Text: see wat i mean bout  friidays its called lose  friday smh
# Sentiment Score: -0.07850531548326313
# Sentiment: negative
# Actual Sentiment: neutral
# ratio: 0.96
#
# Text: the free fillin app on my ipod is fun im addicted
# Sentiment Score: 0.0029233421364834485
# ID: e00c6ef376
# Text: the free fillin app on my ipod is fun im addicted
# Sentiment Score: 0.0029233421364834485
# Sentiment: positive
# Actual Sentiment: positive
# ratio: 0.9615384615384616
#
# Text:   im sorry
# Sentiment Score: -0.15393724039363907
# ID: 852edc3769
# Text:   im sorry
# Sentiment Score: -0.15393724039363907
# Sentiment: negative
# Actual Sentiment: negative
# ratio: 0.9629629629629629
#
# Text: on the way to malaysiano internet access to twit
# Sentiment Score: -0.004576839361588711
# ID: bdc32ea43c
# Text: on the way to malaysiano internet access to twit
# Sentiment Score: -0.004576839361588711
# Sentiment: negative
# Actual Sentiment: negative
# ratio: 0.9642857142857143
#
# Text: juss came backk from berkeleyy  omg its madd fun out there  havent been out there in a minute  whassqoodd
# Sentiment Score: -0.04176543992754188
# ID: 6ce4a4954b
# Text: juss came backk from berkeleyy  omg its madd fun out there  havent been out there in a minute  whassqoodd
# Sentiment Score: -0.04176543992754188
# Sentiment: negative
# Actual Sentiment: positive
# ratio: 0.9310344827586207
#
# Text: went to sleep and there is a power cut in noida  power back up not working too
# Sentiment Score: -0.029811812752724706
# ID: d22e6d40a7
# Text: went to sleep and there is a power cut in noida  power back up not working too
# Sentiment Score: -0.029811812752724706
# Sentiment: negative
# Actual Sentiment: negative
# ratio: 0.9333333333333333
#
# Text: im going home now have you seen my new twitter design quiteheavenly isn
# Sentiment Score: -0.022224371699461405
# ID: d33f811375
# Text: im going home now have you seen my new twitter design quiteheavenly isn
# Sentiment Score: -0.022224371699461405
# Sentiment: negative
# Actual Sentiment: positive
# ratio: 0.9032258064516129
#
# Text: i hope unni will make the audition  fighting dahye unni
# Sentiment Score: -0.060902235552752794
# ID: 7d8c4c11e4
# Text: i hope unni will make the audition  fighting dahye unni
# Sentiment Score: -0.060902235552752794
# Sentiment: negative
# Actual Sentiment: positive
# ratio: 0.875
#
# Text:  if it is any consolation i got my bmi tested hahaha it says i am obesed  well so much for being unhappy for about  minutes
# Sentiment Score: -0.044849826660940444
# ID: 1c31703aef
# Text:  if it is any consolation i got my bmi tested hahaha it says i am obesed  well so much for being unhappy for about  minutes
# Sentiment Score: -0.044849826660940444
# Sentiment: negative
# Actual Sentiment: negative
# ratio: 0.8787878787878788
#
# Text:  thats very funny  cute kids
# Sentiment Score: -0.0028401379237386866
# ID: 2dc51711bc
# Text:  thats very funny  cute kids
# Sentiment Score: -0.0028401379237386866
# Sentiment: negative
# Actual Sentiment: positive
# ratio: 0.8529411764705882
#
# Text:  ahhh i slept through the game  im gonna try my best to watch tomorrow though i hope we play army
# Sentiment Score: -0.005895363890893417
# ID: d21ab5855b
# Text:  ahhh i slept through the game  im gonna try my best to watch tomorrow though i hope we play army
# Sentiment Score: -0.005895363890893417
# Sentiment: negative
# Actual Sentiment: neutral
# ratio: 0.8571428571428571
#
# Text: thats it its the end tears for fears vs eric prydz dj hero
# Sentiment Score: -0.02401006003040151
# ID: 4f5267ad70
# Text: thats it its the end tears for fears vs eric prydz dj hero
# Sentiment Score: -0.02401006003040151
# Sentiment: negative
# Actual Sentiment: neutral
# ratio: 0.8611111111111112
#
# Text: born and raised in nyc and living in texas for the past  years  i still miss ny
# Sentiment Score: -0.01574610854466331
# ID: 2724775d6b
# Text: born and raised in nyc and living in texas for the past  years  i still miss ny
# Sentiment Score: -0.01574610854466331
# Sentiment: negative
# Actual Sentiment: negative
# ratio: 0.8648648648648649
#
# Text: just in case you wonder we are really busy today and this coming with with adding tons of new blogs and updates stay tuned
# Sentiment Score: 0.01683820179709845
# ID: 1cbc812ece
# Text: just in case you wonder we are really busy today and this coming with with adding tons of new blogs and updates stay tuned
# Sentiment Score: 0.01683820179709845
# Sentiment: positive
# Actual Sentiment: neutral
# ratio: 0.868421052631579
#
# Text: im soooooo sleeeeepy the last day o school was todaysniffle
# Sentiment Score: -0.0073755561833961335
# ID: 4b61dffbeb
# Text: im soooooo sleeeeepy the last day o school was todaysniffle
# Sentiment Score: -0.0073755561833961335
# Sentiment: negative
# Actual Sentiment: negative
# ratio: 0.8717948717948718
#
# Text: a little happy for the wine jeje ok itsm my free time so who cares jaja i love this day
# Sentiment Score: 0.014676762987860675
# ID: 2863f435bd
# Text: a little happy for the wine jeje ok itsm my free time so who cares jaja i love this day
# Sentiment Score: 0.014676762987860675
# Sentiment: positive
# Actual Sentiment: positive
# ratio: 0.875
#
# Text:  car not happy big big dent in boot hoping theyre not going to write it off crossing fingers and waiting
# Sentiment Score: -0.049415860676458936
# ID: d93afa85cf
# Text:  car not happy big big dent in boot hoping theyre not going to write it off crossing fingers and waiting
# Sentiment Score: -0.049415860676458936
# Sentiment: negative
# Actual Sentiment: neutral
# ratio: 0.8780487804878049
#
# Text: im an avid fan of  magazine and i love your magazines
# Sentiment Score: -0.005425347367938507
# ID: fab6b7d16c
# Text: im an avid fan of  magazine and i love your magazines
# Sentiment Score: -0.005425347367938507
# Sentiment: negative
# Actual Sentiment: positive
# ratio: 0.8571428571428571
#
# Text: mayday
# Sentiment Score: -0.13843835019805426
# ID: 2e7082d1c8
# Text: mayday
# Sentiment Score: -0.13843835019805426
# Sentiment: negative
# Actual Sentiment: neutral
# ratio: 0.8604651162790697
#
# Text: ratt rocked nashville toniteone thing sucked no encore  like in the  they still have a fun show pearcy has that hott bad boy look
# Sentiment Score: -0.02601499960249832
# ID: 684081e4e7
# Text: ratt rocked nashville toniteone thing sucked no encore  like in the  they still have a fun show pearcy has that hott bad boy look
# Sentiment Score: -0.02601499960249832
# Sentiment: negative
# Actual Sentiment: neutral
# ratio: 0.8636363636363636
#
# Text:  i love to but im only available from   and where dear would love to help  convert her vidsï¿½
# Sentiment Score: 0.02246633534468966
# ID: c77717b103
# Text:  i love to but im only available from   and where dear would love to help  convert her vidsï¿½
# Sentiment Score: 0.02246633534468966
# Sentiment: positive
# Actual Sentiment: positive
# ratio: 0.8666666666666667
#
# Text: the girl in the hair salon asked me shall i trim your eyebrows how old do i feel
# Sentiment Score: -0.0014145037442818734
# ID: a9d499e123
# Text: the girl in the hair salon asked me shall i trim your eyebrows how old do i feel
# Sentiment Score: -0.0014145037442818734
# Sentiment: negative
# Actual Sentiment: neutral
# ratio: 0.8695652173913043
#
# Text: egh blah and boooooooooooo i dunno wanna go to work  hangovers suckkkkkk im a drunk mess
# Sentiment Score: -0.06792088768561136
# ID: ddf296dffa
# Text: egh blah and boooooooooooo i dunno wanna go to work  hangovers suckkkkkk im a drunk mess
# Sentiment Score: -0.06792088768561136
# Sentiment: negative
# Actual Sentiment: negative
# ratio: 0.8723404255319149
#
# Text: visiting my friendster and facebook
# Sentiment Score: -0.004428242382863788
# ID: c3924dc9e4
# Text: visiting my friendster and facebook
# Sentiment Score: -0.004428242382863788
# Sentiment: negative
# Actual Sentiment: neutral
# ratio: 0.875
#
# Text: i donbt like to peel prawns i also dont like going shopping running out of money and crawling round the car looking for more
# Sentiment Score: -0.05431876520210404
# ID: 3d9d4b0b55
# Text: i donbt like to peel prawns i also dont like going shopping running out of money and crawling round the car looking for more
# Sentiment Score: -0.05431876520210404
# Sentiment: negative
# Actual Sentiment: negative
# ratio: 0.8775510204081632
#
# Text:  which case i got a new one last week and im not thrilled at all with mine
# Sentiment Score: 0.002058406277918014
# ID: 3fcea4debc
# Text:  which case i got a new one last week and im not thrilled at all with mine
# Sentiment Score: 0.002058406277918014
# Sentiment: positive
# Actual Sentiment: negative
# ratio: 0.86
#
# Text:  then you should check out  and connect with other tweeple who hate twitter
# Sentiment Score: -0.017422277011318665
# ID: a3ae670885
# Text:  then you should check out  and connect with other tweeple who hate twitter
# Sentiment Score: -0.017422277011318665
# Sentiment: negative
# Actual Sentiment: neutral
# ratio: 0.8627450980392157
